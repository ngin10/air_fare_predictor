# %% [markdown]
# <a href="https://colab.research.google.com/github/ngin10/air_fare_predictor/blob/main/Untitled75.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Clean_Dataset.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
#
#   arrival_time destination_city    class  duration  days_left   price
# 0        Night           Mumbai  Economy      2.17        1.0  5953.0
# 1      Morning           Mumbai  Economy      2.33        1.0  5953.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104215 entries, 0 to 104214
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        104215 non-null  int64
#  1   airline           104215 non-null  object
#  2   flight            104215 non-null  object
#  3   source_city       104215 non-null  object
#  4   departure_time    104215 non-null  object
#  5   stops             104215 non-null  object
#  6   arrival_time      104215 non-null  object
#  7   destination_city  104215 non-null  object
#  8   class             104215 non-null  object
#  9   duration          104215 non-null  float64
#  10  days_left         104215 non-null  float64
#  11  price             104215 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 10.3+ MB

# %%
df[df['duration'].isna()]
# Out:
#         Unnamed: 0  airline   flight source_city departure_time stops  \
# 104215      104215  AirAsia  I5-2461   Bangalore        Evening   one
#
#        arrival_time destination_city  class  duration  days_left  price
# 104215   Late_Night          Kolkata  Econo       NaN        NaN    NaN

# %%
df.dropna(inplace=True)

# %%
df['price'].agg(['min','max','mean','median','std'])
# Out:
# min        1890.000000
# max       40354.000000
# mean       6384.752857
# median     5547.000000
# std        3678.470738
# Name: price, dtype: float64

# %%
sns.kdeplot(df['price'],fill=True,color='#e80e0e')
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
price=df[df['price']>14000]

# %%
price['source_city'].value_counts().reset_index()
# Out:
#   source_city  count
# 0       Delhi   1844
# 1      Mumbai   1832
# 2   Bangalore   1040

# %%
sns.countplot(price['source_city'],palette='viridis')
# Out:
# <Axes: xlabel='count', ylabel='source_city'>

# %%
price['destination_city'].value_counts().reset_index()
# Out:
#   destination_city  count
# 0          Kolkata   1348
# 1          Chennai    765
# 2           Mumbai    762
# 3        Bangalore    747
# 4            Delhi    736
# 5        Hyderabad    358

# %%
sns.countplot(price['destination_city'],palette='flare')
# Out:
# <Axes: xlabel='count', ylabel='destination_city'>

# %%
sns.kdeplot(np.log1p(df['price']))
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
day=df['days_left'].value_counts().reset_index()

# %%
plt.figure(figsize=(10, 14))  # Increase width and height
sns.barplot(data=day, y=day['days_left'].sort_values(ascending=False), x='count', palette='flare', orient='h')
plt.xlabel('Count')
plt.ylabel('Days Left')
plt.title('Distribution of Days Left')
plt.tight_layout()
plt.show()

# %%
day.agg(['min','max','mean','median','std'])
# Out:
#         days_left        count
# min       1.00000  1163.000000
# max      49.00000  2380.000000
# mean     25.00000  2126.836735
# median   25.00000  2212.000000
# std      14.28869   218.138941

# %%
sns.kdeplot(day['days_left'],fill=True)
# Out:
# <Axes: xlabel='days_left', ylabel='Density'>

# %%
corr1=df[['price','days_left']]

# %%
corr1.corr()
# Out:
#               price  days_left
# price      1.000000  -0.571383
# days_left -0.571383   1.000000

# %%
sns.heatmap(corr1.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.lineplot(data=corr1,x='days_left',y='price',color='#e80e0e',marker='o')
# Out:
# <Axes: xlabel='days_left', ylabel='price'>

# %%
sns.histplot(df['duration'],bins=120,color='#e80e0e')
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %%
df['duration'].agg(['min','max','mean','median','std'])
# Out:
# min        1.170000
# max       41.580000
# mean      10.938732
# median     9.500000
# std        7.049259
# Name: duration, dtype: float64

# %%
dur=df[df['duration']<10]

# %%
sns.kdeplot(dur['duration'],fill=True)
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
dur1=dur[['source_city','destination_city']].value_counts().reset_index().sort_values(by='count',ascending=False)

# %%
sns.countplot(data=dur1,y='source_city',palette='flare')
# Out:
# <Axes: xlabel='count', ylabel='source_city'>

# %%
sns.countplot(data=dur1,y='destination_city',palette='flare')
# Out:
# <Axes: xlabel='count', ylabel='destination_city'>

# %%
df[['price','duration']].corr()
# Out:
#              price  duration
# price     1.000000  0.268596
# duration  0.268596  1.000000

# %%
sns.heatmap(df[['price','duration']].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
plt.figure(figsize=(15,6))
sns.lineplot(data=df,x='duration',y='price',color='#e80e0e',ci=None)
plt.title('Price vs Duration')
plt.show()

# %%
dur2=df[df['duration']>24]

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=dur2,x='duration',y='price',color='#e80e0e',ci=None)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df,x='duration',y='price',color='#e80e0e')
# Out:
# <Axes: xlabel='duration', ylabel='price'>

# %%
df['class'].value_counts()
# Out:
# class
# Economy    104215
# Name: count, dtype: int64

# %%
df['arrival_time'].value_counts()
# Out:
# arrival_time
# Night            31104
# Evening          25171
# Morning          21451
# Afternoon        13950
# Late_Night        6351
# Early_Morning     6188
# Name: count, dtype: int64

# %%
plt.figure(figsize=(24,10))
plt.subplot(1,2,1)
sns.boxplot(x='source_city',y='price',data=df,palette='flare')
plt.title('Source City Vs Ticket Price',fontsize=20)
plt.xlabel('Source City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.subplot(1,2,2)
sns.boxplot(x='destination_city',y='price',data=df,palette='hls')
plt.title('Destination City Vs Ticket Price',fontsize=20)
plt.xlabel('Destination City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=df,x='days_left',y='price',color='blue',hue='airline',palette='hls')
plt.title('Days Left For Departure Versus Ticket Price of each Airline',fontsize=15)
plt.legend(fontsize=12)
plt.xlabel('Days Left for Departure',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %%
sns.countplot(df['arrival_time'],palette='flare')
# Out:
# <Axes: xlabel='count', ylabel='arrival_time'>

# %%
df[['duration','price']].corr()
# Out:
#           duration     price
# duration  1.000000  0.268596
# price     0.268596  1.000000

# %%
sns.heatmap(df[['duration','price']].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['airline'].value_counts()
# Out:
# airline
# Vistara      31111
# Air_India    24831
# Indigo       19949
# GO_FIRST     14191
# AirAsia       8905
# SpiceJet      5228
# Name: count, dtype: int64

# %%
sns.countplot(df['airline'],palette='flare')
# Out:
# <Axes: xlabel='count', ylabel='airline'>

# %%
df[['airline','price']].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-aa679ff83b75> in <cell line: 0>()
# ----> 1 df[['airline','price']].corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype=='object':
        df[col]=le.fit_transform(df[col])

# %%
y=df['price']
x=df.drop('price',axis=1)

# %%
# Scaling the values to convert the int values to Machine Languages
from sklearn.preprocessing import MinMaxScaler
mmscaler=MinMaxScaler(feature_range=(0,1))
x_train=mmscaler.fit_transform(x_train)
x_test=mmscaler.fit_transform(x_test)
x_train=pd.DataFrame(x_train)
x_test=pd.DataFrame(x_test)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
mod1=LinearRegression()
mod1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
mod1.score(x_train,y_train)
# Out:
# 0.893940902304083

# %%
mod1.score(x_test,y_test)
# Out:
# 0.8944716815860728

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_train,y_train)
# Out:
# 0.9986774911143578

# %%
rf.score(x_test,y_test)
# Out:
# 0.9907286323186802

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
import pandas as pd # Import pandas for DataFrame initialization
import numpy as np # Import numpy for calculations like sqrt and log
from sklearn import metrics # Import metrics for evaluation

# Create objects of Regression / Regressor models with default hyper-parameters

modelmlg = LinearRegression()
modeldcr = DecisionTreeRegressor()
modelbag = BaggingRegressor()
modelrfr = RandomForestRegressor()
modelSVR = SVR()
modelXGR = xgb.XGBRegressor()
modelKNN = KNeighborsRegressor(n_neighbors=5)
modelETR = ExtraTreesRegressor()
modelRE=Ridge()
modelLO=linear_model.Lasso(alpha=0.1)

modelGBR = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0,
                                     criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1,
                                     min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0,
                                     init=None, random_state=None, max_features=None,
                                     alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False,
                                     validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# Evalution matrix for all the algorithms

MM = [modelmlg, modeldcr, modelrfr, modelKNN, modelETR, modelGBR, modelXGR, modelbag,modelRE,modelLO]

# Initialize an empty list to store results
results_list = []

for models in MM:

    # Fit the model with train data

    models.fit(x_train, y_train)

    # Predict the model with test data

    y_pred = models.predict(x_test)

    # Print the model name

    print('Model Name: ', models)

    # Evaluation metrics for Regression analysis


    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    # Handle potential negative values from MSE before taking log
    if metrics.mean_squared_error(y_test, y_pred) > 0:
        print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    else:
         print('Root Mean Squared Log Error (RMSLE):', float('-inf')) # Or handle as appropriate


    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        # Avoid division by zero
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 if not np.any(y_test == 0) else np.nan


    # Evaluation of MAPE

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')

    # Calculate Adjusted R squared values

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    # Avoid division by zero in adjusted R-squared calculation
    if (len(y)-x.shape[1]-1) != 0:
        adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    else:
        adjusted_r_squared = np.nan # Or handle as appropriate
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))) if metrics.mean_squared_error(y_test, y_pred) > 0 else float('-inf'),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    # Append the new row dictionary to the list
    results_list.append(new_row)

# Convert the list of dictionaries to a DataFrame after the loop
Results = pd.DataFrame(results_list)
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 0.283
# Mean Squared Error (MSE): 0.131
# Root Mean Squared Error (RMSE): 0.362
# R2_score: 0.894472
# Root Mean Squared Log Error (RMSLE): -1.017
# Mean Absolute Percentage Error (MAPE): 3.13 %
# Adj R Square:  0.894468
# ------------------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 0.047
# Mean Squared Error (MSE): 0.019
# Root Mean Squared Error (RMSE): 0.138
# R2_score: 0.984643
# Root Mean Squared Log Error (RMSLE): -1.981
# Mean Absolute Percentage Error (MAPE): 0.52 %
# Adj R Square:  0.984642
# ------------------------------------------------------------------------------------------------------------
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 0.048
# Mean Squared Error (MSE): 0.011
# Root Mean Squared Error (RMSE): 0.107
# R2_score: 0.990724
# ...

# %%
Results
# Out:
#                                           Model Name  Mean_Absolute_Error_MAE  \
# 0                                 LinearRegression()                 0.283391
# 1                            DecisionTreeRegressor()                 0.047184
# 2  (DecisionTreeRegressor(max_features=1.0, rando...                 0.047693
# 3                              KNeighborsRegressor()                 0.115852
# 4  (ExtraTreeRegressor(random_state=2110116559), ...                 0.047918
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...                 0.173809
# 6  XGBRegressor(base_score=None, booster=None, ca...                 0.109407
# 7  (DecisionTreeRegressor(random_state=733393300)...                 0.050010
# 8                                            Ridge()                 0.283391
# 9                                   Lasso(alpha=0.1)                 0.424906
#
#    Adj_R_Square  Root_Mean_Squared_Error_RMSE  \
# 0      0.894468                      0.361526
# ...

# %%
residuals = y_test - y_pred

plt.figure(figsize=(8, 4))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Distribution of Residuals")
plt.xlabel("Error")
plt.show()
